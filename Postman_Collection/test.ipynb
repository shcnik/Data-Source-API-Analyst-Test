# %%
import requests
import os
from time import sleep
from datetime import datetime

from github import *

# %% [markdown]
# Check getting info about repository:

# %%
client = GHClient('2022-11-28', 'DataSource Analyst Challenge', personal_token='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')
try:
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test')
  print(repo)
except GHAccessError as e:
  print(e.msg, ':', e.cmd)
except GHRateLimitError as e:
  e.wait()
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test')
  print(repo)
# Out:
# {'id': 894443468, 'node_id': 'R_kgDONVAfzA', 'name': 'Data-Source-API-Analyst-Test', 'full_name': 'shcnik/Data-Source-API-Analyst-Test', 'private': False, 'owner': {'login': 'shcnik', 'id': 111297939, 'node_id': 'U_kgDOBqJFkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/111297939?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/shcnik', 'html_url': 'https://github.com/shcnik', 'followers_url': 'https://api.github.com/users/shcnik/followers', 'following_url': 'https://api.github.com/users/shcnik/following{/other_user}', 'gists_url': 'https://api.github.com/users/shcnik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/shcnik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/shcnik/subscriptions', 'organizations_url': 'https://api.github.com/users/shcnik/orgs', 'repos_url': 'https://api.github.com/users/shcnik/repos', 'events_url': 'https://api.github.com/users/shcnik/events{/privacy}', 'received_events_url': 'https://api.
# ...

# %% [markdown]
# Check getting list of user's repositories

# %%
try:
  lst = client.list_user_repositories('shcnik', per_page=5)
  for record in lst:
    print(record)
except GHAccessError as e:
  print(e.msg, ':', e.cmd)
except GHRateLimitError as e:
  e.wait()
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test')
  print(repo.json())
# Out:
# {'id': 894443468, 'node_id': 'R_kgDONVAfzA', 'name': 'Data-Source-API-Analyst-Test', 'full_name': 'shcnik/Data-Source-API-Analyst-Test', 'private': False, 'owner': {'login': 'shcnik', 'id': 111297939, 'node_id': 'U_kgDOBqJFkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/111297939?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/shcnik', 'html_url': 'https://github.com/shcnik', 'followers_url': 'https://api.github.com/users/shcnik/followers', 'following_url': 'https://api.github.com/users/shcnik/following{/other_user}', 'gists_url': 'https://api.github.com/users/shcnik/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/shcnik/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/shcnik/subscriptions', 'organizations_url': 'https://api.github.com/users/shcnik/orgs', 'repos_url': 'https://api.github.com/users/shcnik/repos', 'events_url': 'https://api.github.com/users/shcnik/events{/privacy}', 'received_events_url': 'https://api.
# ...

# %% [markdown]
# Check getting list of commits in repository:

# %%
try:
  lst = client.list_commits('shcnik/Data-Source-API-Analyst-Test')
  for record in lst:
    print(record)
except GHAccessError as e:
  print(e.msg, ':', e.cmd)
except GHRateLimitError as e:
  e.wait()
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test')
  print(repo.json())
# Out:
# {'sha': 'e257f6ab6b5349cf4fc8305832246809e5eec812', 'node_id': 'C_kwDONVAfzNoAKGUyNTdmNmFiNmI1MzQ5Y2Y0ZmM4MzA1ODMyMjQ2ODA5ZTVlZWM4MTI', 'commit': {'author': {'name': 'attaccopigmeo', 'email': 'camillaschmidt@yandex.ru', 'date': '2024-11-27T09:10:51Z'}, 'committer': {'name': 'attaccopigmeo', 'email': 'camillaschmidt@yandex.ru', 'date': '2024-11-27T09:10:51Z'}, 'message': 'Wrote API code', 'tree': {'sha': 'aaa6e0b443cc86aff26de8e9c13370d958fd0a8e', 'url': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/git/trees/aaa6e0b443cc86aff26de8e9c13370d958fd0a8e'}, 'url': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/git/commits/e257f6ab6b5349cf4fc8305832246809e5eec812', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None, 'verified_at': None}}, 'url': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/commits/e257f6ab6b5349cf4fc8305832246809e5eec812', 'html_url': 'https://github.com
# ...

# %% [markdown]
# Check getting list of content in repository:

# %%
try:
  contents = client.get_contents('shcnik/Data-Source-API-Analyst-Test', '/Content/github')
  for c in contents:
    print(c)
except GHAccessError as e:
  print(e.msg, ':', e.cmd)
except GHRateLimitError as e:
  e.wait()
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test')
  print(repo.json())
# Out:
# {'name': 'Content', 'path': 'Content', 'sha': 'a9b46f1b074674a184190280ef863bd8d2fe2aa0', 'size': 0, 'url': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/contents/Content?ref=master', 'html_url': 'https://github.com/shcnik/Data-Source-API-Analyst-Test/tree/master/Content', 'git_url': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/git/trees/a9b46f1b074674a184190280ef863bd8d2fe2aa0', 'download_url': None, 'type': 'dir', '_links': {'self': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/contents/Content?ref=master', 'git': 'https://api.github.com/repos/shcnik/Data-Source-API-Analyst-Test/git/trees/a9b46f1b074674a184190280ef863bd8d2fe2aa0', 'html': 'https://github.com/shcnik/Data-Source-API-Analyst-Test/tree/master/Content'}}
# ...

# %% [markdown]
# Check error handling:

# %%
try:
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test-false')
  print(repo)
except GHAccessError as e:
  print(e.msg, ':', e.cmd)
except GHRateLimitError as e:
  e.wait()
  repo = client.get_repository('shcnik/Data-Source-API-Analyst-Test')
  print(repo)
# Out:
# Resource not found : repos/shcnik/Data-Source-API-Analyst-Test-false
